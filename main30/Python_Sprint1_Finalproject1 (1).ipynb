# %% [markdown]
# # **Project Name - Weather Data Analysis of banglore and mumbai city**

# %% [markdown]
#  Weather Data Analysis of Bangalore City and Mumbai city(1990-2022)
#
#  Objective:
#
#  1.To analyze and interpret weather data of Bangalore from 1990 to 2022 to
#
# identify month'year and day wise understanding climate pattern to this main city
#
#  2.comparision the which year or which month rainfall was highest in banglore or mumbai
#
#  3.To compare the two cities mumbai and bangloreHigher daily precipitation average in 2016 compared to 1990

# %%
# Installing the packages
# !pip install panda
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=978beb07aaffe8749e7d33efeb327bfa4c87f7edf06d71a8d8302d51ba0dcc93
#   Stored in directory: /root/.cache/pip/wheels/0e/8b/c3/ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# ...

# %% [markdown]
# # *Import necessary packages*

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # *Loading the files from the local system to the Notebook*
#
# ```
# # This is formatted as code
# ```

# %%
bangalore_df = pd.read_csv('Bangalore_1990_2022_BangaloreCity.csv')
mumbai_df = pd.read_csv('Mumbai_1990_2022_Santacruz.csv')

# %% [markdown]
# #Data set view of banglore City

# %%
print(bangalore_df.shape)
bangalore_df.head()
# Out:
# (11894, 5)
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  22.9  19.1  28.4   NaN
# 1  02-01-1990  21.7   NaN  26.5   0.0
# 2  03-01-1990  21.0  16.4  26.5   0.0
# 3  04-01-1990  20.8   NaN  27.4   0.0
# 4  05-01-1990  20.4  14.2  26.1   0.0

# %% [markdown]
# #Data set view of Mumbai City and banglore city

# %%
print(mumbai_df.shape)
mumbai_df.head()
# Out:
# (11894, 5)
#          time  tavg  tmin  tmax  prcp
# 0  01-01-1990  23.2  17.0   NaN   0.0
# 1  02-01-1990  22.2  16.5  29.9   0.0
# 2  03-01-1990  21.8  16.3  30.7   0.0
# 3  04-01-1990  25.4  17.9  31.8   0.0
# 4  05-01-1990  26.5  19.3  33.7   0.0

# %%
print(bangalore_df.shape)
bangalore_df.tail()
# Out:
# (11894, 5)
#              time  tavg  tmin  tmax  prcp
# 11889  21-07-2022  23.7  20.5  30.8  82.5
# 11890  22-07-2022  23.2  21.1  27.9   0.0
# 11891  23-07-2022  23.1  20.9  26.7   0.0
# 11892  24-07-2022  22.8  20.0  26.7   0.3
# 11893  25-07-2022  24.1  20.2  28.5   0.5

# %%
print(mumbai_df.shape)
mumbai_df.tail()
# Out:
# (11894, 5)
#              time  tavg  tmin  tmax  prcp
# 11889  21-07-2022  27.6  25.6  30.5  10.9
# 11890  22-07-2022  28.3  26.0  30.5   3.0
# 11891  23-07-2022  28.2  25.8  31.3   5.1
# 11892  24-07-2022  28.1  25.6  30.4   7.1
# 11893  25-07-2022  28.3  25.1  30.2   7.1

# %% [markdown]
# #Dataset information of both city
#
# > Add blockquote

# %%
bangalore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11894 entries, 0 to 11893
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    11894 non-null  object
#  1   tavg    11824 non-null  float64
#  2   tmin    10505 non-null  float64
#  3   tmax    11265 non-null  float64
#  4   prcp    7274 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 464.7+ KB

# %%
mumbai_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11894 entries, 0 to 11893
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    11894 non-null  object
#  1   tavg    11883 non-null  float64
#  2   tmin    9440 non-null   float64
#  3   tmax    9987 non-null   float64
#  4   prcp    7213 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 464.7+ KB

# %% [markdown]
# # The format was specified to match the input data format (day-month-year)

# %%
bangalore_df['time'] = pd.to_datetime(bangalore_df['time'], format='%d-%m-%Y')

# %%
mumbai_df['time'] = pd.to_datetime(mumbai_df['time'], format='%d-%m-%Y')

# %% [markdown]
# #setting the time as index

# %%
bangalore_df.set_index(['time'], inplace = True)

# %%
mumbai_df.set_index(['time'], inplace = True)

# %% [markdown]
# #Missing Values of banglore and mumbai dataset

# %%
#finding percentage of null values in the data
drop_df = bangalore_df.dropna()

missing_pctg = round((drop_df.shape[0]/bangalore_df.shape[0])*100,2)
print(missing_pctg,'% of data contain NaN values')
# Out:
# 51.14 % of data contain NaN values

# %%
#finding percentage of null values in the data
drop_df = mumbai_df.dropna()

missing_pctg = round((drop_df.shape[0]/mumbai_df.shape[0])*100,2)
print(missing_pctg,'% of data contain NaN values')
# Out:
# 38.87 % of data contain NaN values

# %%
bangalore_df[bangalore_df.isna().sum(axis=1) > 3]
# Out:
#             tavg  tmin  tmax  prcp
# time
# 1990-05-26   NaN   NaN   NaN   NaN
# 1990-05-27   NaN   NaN   NaN   NaN
# 1990-05-28   NaN   NaN   NaN   NaN
# 1990-05-29   NaN   NaN   NaN   NaN
# 1990-05-30   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...
# 2003-06-27   NaN   NaN   NaN   NaN
# 2007-05-20   NaN   NaN   NaN   NaN
# 2007-08-28   NaN   NaN   NaN   NaN
# 2007-10-22   NaN   NaN   NaN   NaN
# 2009-06-17   NaN   NaN   NaN   NaN
#
# [70 rows x 4 columns]

# %%
mumbai_df[mumbai_df.isna().sum(axis=1) > 3]
# Out:
#             tavg  tmin  tmax  prcp
# time
# 1990-05-26   NaN   NaN   NaN   NaN
# 1990-05-27   NaN   NaN   NaN   NaN
# 1990-05-28   NaN   NaN   NaN   NaN
# 1990-05-29   NaN   NaN   NaN   NaN
# 1990-12-27   NaN   NaN   NaN   NaN
# 1991-05-15   NaN   NaN   NaN   NaN
# 1993-12-19   NaN   NaN   NaN   NaN
# 1994-05-22   NaN   NaN   NaN   NaN
# 1994-10-07   NaN   NaN   NaN   NaN
# 1995-03-29   NaN   NaN   NaN   NaN
# 1999-01-10   NaN   NaN   NaN   NaN

# %%
bangalore_df = bangalore_df.dropna(how='all') #dropping rows with no data in all columns

# %%
mumbai_df = mumbai_df.dropna(how='all') #dropping rows with no data in all columns

# %%
bangalore_df = bangalore_df.interpolate(method='time') #using interpolate to fill in NaN values

# %%
mumbai_df = mumbai_df .interpolate(method='time') #using interpolate to fill in NaN values

# %%
bangalore_df.isna().sum()
# Out:
# tavg    0
# tmin    0
# tmax    0
# prcp    1
# dtype: int64

# %%
mumbai_df.isna().sum()
# Out:
# tavg    0
# tmin    0
# tmax    1
# prcp    0
# dtype: int64

# %%
bangalore_df.head()
# Out:
#             tavg   tmin  tmax  prcp
# time
# 1990-01-01  22.9  19.10  28.4   NaN
# 1990-01-02  21.7  17.75  26.5   0.0
# 1990-01-03  21.0  16.40  26.5   0.0
# 1990-01-04  20.8  15.30  27.4   0.0
# 1990-01-05  20.4  14.20  26.1   0.0

# %%
mumbai_df.head()
# Out:
#             tavg  tmin  tmax  prcp
# time
# 1990-01-01  23.2  17.0   NaN   0.0
# 1990-01-02  22.2  16.5  29.9   0.0
# 1990-01-03  21.8  16.3  30.7   0.0
# 1990-01-04  25.4  17.9  31.8   0.0
# 1990-01-05  26.5  19.3  33.7   0.0

# %%
bangalore_df.fillna(0,inplace=True) #filling the leftover nan value

# %%
mumbai_df.fillna(0,inplace=True) #filling the leftover nan value

# %%
bangalore_df.isna().sum()
# Out:
# tavg    0
# tmin    0
# tmax    0
# prcp    0
# dtype: int64

# %%
mumbai_df.isna().sum()
# Out:
# tavg    0
# tmin    0
# tmax    0
# prcp    0
# dtype: int64

# %% [markdown]
# #Exploratory Data Analysis(EDA)
#  to analyze and summarize datasets to uncover patterns, spot anomalies, test hypotheses, and check assumptions through statistical and graphical techniques.

# %%
#date at which temperature(tmax) was highest
bangalore_df[bangalore_df['tmax'] == max(bangalore_df['tmax'])]
#date at which temperature(tmax) was highest
mumbai_df[mumbai_df['tmax'] == max(mumbai_df['tmax'])]
# Out:
#             tavg  tmin  tmax  prcp
# time
# 2011-03-16  32.8  19.2  41.3   0.0

# %%
#date at which temperature(tmin) was lowest
mumbai_df[mumbai_df['tmin'] == min(mumbai_df['tmin'])]
# Out:
#             tavg  tmin  tmax      prcp
# time
# 2008-02-08  17.9   8.5  22.3  0.564655

# %%
#date at which precipitation was the highest
bangalore_df[bangalore_df['prcp'] == max(bangalore_df['prcp'])]
#date at which precipitation was the highest
[mumbai_df['prcp'] == max(mumbai_df['prcp'])]
# Out:
# [time
#  1990-01-01    False
#  1990-01-02    False
#  1990-01-03    False
#  1990-01-04    False
#  1990-01-05    False
#                ...
#  2022-07-21    False
#  2022-07-22    False
#  2022-07-23    False
#  2022-07-24    False
#  2022-07-25    False
#  Name: prcp, Length: 11883, dtype: bool]

# %%
plt.style.use('bmh')
bangalore_df[['tavg','tmax','tmin','prcp']].plot(subplots=True, figsize=(18,10));

# %%
plt.style.use('bmh')
mumbai_df[['tavg','tmax','tmin','prcp']].plot(subplots=True, figsize=(18,10));

# %%
bangalore_year = bangalore_df.groupby(bangalore_df.index.year).mean()
mumbai_year = mumbai_df.groupby(mumbai_df.index.year).mean()

# %%
bangalore_year #yearwise averages
# Out:
#            tavg       tmin       tmax      prcp
# time
# 1990  23.703134  19.092016  29.341728  2.120106
# 1991  23.626111  19.138657  29.247454  4.191528
# 1992  23.224148  18.472025  29.127367  2.318466
# 1993  23.637673  18.887673  29.518975  2.418144
# 1994  23.427072  19.000138  29.165447  2.321685
# 1995  23.888611  19.214630  29.475139  3.213194
# 1996  23.633611  18.919583  29.729653  2.714167
# 1997  23.667222  19.469028  29.939495  3.284537
# 1998  24.226099  19.895604  30.137088  3.729239
# 1999  23.547645  18.991898  29.627285  4.557024
# 2000  23.438630  19.014247  29.487671  3.475623
# 2001  23.771507  19.462329  29.689315  2.940525
# 2002  24.055647  19.330716  30.271901  3.116897
# 2003  24.224518  19.612810  30.563590  2.136685
# 2004  23.395628  18.900000  29.540574  3.104508
# 2005  23.687123  19.289315  29.693836  4.840000
# 2006  23.738904  19.223699  29.895616  5.408219
# 2007  23.856077  19.249678  29.851105  8.153315
# ...

# %%
mumbai_year #yearwise averages
# Out:
#            tavg       tmin       tmax       prcp
# time
# 1990  27.076944  22.633148  31.716944   7.349167
# 1991  26.933791  22.353709  31.864560   6.273352
# 1992  27.109836  22.608607  32.060383   5.252869
# 1993  27.175549  22.843681  31.908242   6.724038
# 1994  26.939118  22.441368  31.830441   7.063912
# 1995  27.254396  22.641896  32.375137   4.750412
# 1996  27.636612  22.550000  32.187432   5.794536
# 1997  27.657808  22.433425  32.333230   5.149315
# 1998  27.746575  23.072192  32.370743   7.071609
# 1999  27.651374  22.591667  32.466071   5.708142
# 2000  27.609016  22.304736  32.371585   6.187158
# 2001  27.256438  22.617169  32.247515   5.499921
# 2002  27.819452  23.260411  32.693581   3.557065
# 2003  27.463288  23.032260  32.315342   6.215068
# 2004  27.003005  22.524795  32.369672   5.885383
# 2005  27.358082  22.074658  32.186575   8.027966
# 2006  27.355616  22.652466  32.538356   8.298198
# 2007  28.023836  22.991096  32.681781   7.756547
# ...

# %%
f, axes = plt.subplots(nrows = 2, figsize =(15,9))
ax = bangalore_year[['tavg','tmin','tmax']].plot(ax=axes[0])
ax.set_ylabel('Temperature (c)')
ax.set_xlabel('Year')
ax.set_title('Average Daily Temperature by Year')

ax = bangalore_year['prcp'].plot(ax=axes[1])
ax.set_ylabel('Precipitation (mm)')
ax.set_xlabel('Year')
ax.set_title('Average Daily Precipitation by Year')

plt.tight_layout()

f, axes = plt.subplots(nrows = 2, figsize =(15,9))
ax = mumbai_year[['tavg','tmin','tmax']].plot(ax=axes[0])
ax.set_ylabel('Temperature (c)')
ax.set_xlabel('Year')
ax.set_title('Average Daily Temperature by Year')

ax = mumbai_year['prcp'].plot(ax=axes[1])
ax.set_ylabel('Precipitation (mm)')
ax.set_xlabel('Year')
ax.set_title('Average Daily Precipitation by Year')

plt.tight_layout()

# %%
# Calculate the overall average temperature for the entire dataset
average_temp = mumbai_df['tavg'].mean()
print(f"The average temperature in Mumbai is {average_temp:.2f}°C.")
# Out:
# The average temperature in Mumbai is 27.76°C.

# %%
#by month
months = ['Jan','Feb','Mar','Apr','May','Jun',
          'Jul','Aug','Sep','Oct','Nov','Dec']

data = bangalore_df.groupby(bangalore_df.index.month, as_index=False)[['tavg','tmin','tmax','prcp']].mean()

f, axes = plt.subplots(nrows=2, figsize=(10,10))
ax = data[['tavg','tmin','tmax']].plot(ax=axes[0])
ax.set_ylabel('Temperature (C)')
ax.set_xlabel('Month')
ax.set_xticks(np.arange(0,12))
ax.set_xticklabels(months)
ax.set_title('Average Daily Temperature by Month')

ax = data['prcp'].plot(ax=axes[1]);
ax.set_ylabel('Precipitation (mm)')
ax.set_xlabel('Month')
ax.set_xticks(np.arange(0,12))
ax.set_xticklabels(months)
ax.set_title('Average Daily Precipitation by Month')

plt.tight_layout()

#by month
months = ['Jan','Feb','Mar','Apr','May','Jun',
          'Jul','Aug','Sep','Oct','Nov','Dec']

data = mumbai_df.groupby(mumbai_df.index.month, as_index=False)[['tavg','tmin','tmax','prcp']].mean()

f, axes = plt.subplots(nrows=2, figsize=(10,10))
ax = data[['tavg','tmin','tmax']].plot(ax=axes[0])
ax.set_ylabel('Temperature (C)')
ax.set_xlabel('Month')
ax.set_xticks(np.arange(0,12))
ax.set_xticklabels(months)
ax.set_title('Average Daily Temperature by Month')

ax = data['prcp'].plot(ax=axes[1]);
ax.set_ylabel('Precipitation (mm)')
ax.set_xlabel('Month')
ax.set_xticks(np.arange(0,12))
ax.set_xticklabels(months)
ax.set_title('Average Daily Precipitation by Month')

plt.tight_layout()
# Out:
# <ipython-input-129-6606c9375219>:5: FutureWarning: A grouping was used that is not in the columns of the DataFrame and so was excluded from the result. This grouping will be included in a future version of pandas. Add the grouping as a column of the DataFrame to silence this warning.
#   data = bangalore_df.groupby(bangalore_df.index.month, as_index=False)[['tavg','tmin','tmax','prcp']].mean()
# <ipython-input-129-6606c9375219>:28: FutureWarning: A grouping was used that is not in the columns of the DataFrame and so was excluded from the result. This grouping will be included in a future version of pandas. Add the grouping as a column of the DataFrame to silence this warning.
#   data = mumbai_df.groupby(mumbai_df.index.month, as_index=False)[['tavg','tmin','tmax','prcp']].mean()

# %%
mumbai_df['year'] = mumbai_df.index.year
mumbai_df['mnth'] = mumbai_df.index.month
bangalore_df['year'] = bangalore_df.index.year
bangalore_df['mnth'] = bangalore_df.index.month

# %%
month_df = bangalore_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()
month_df = mumbai_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()

# %%
# Update the way you are using the pivot function

month_df = bangalore_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()
data = month_df.pivot(index='year', columns='mnth', values='tavg')
data.columns = months

plt.subplots(figsize=(10,10))
sns.heatmap(data, cmap='YlOrRd',annot=True, fmt='.1f')
plt.title('Average Daily Temperature (C) by Month')
plt.yticks(rotation=0)
plt.show()

month_df = mumbai_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()
data = month_df.pivot(index='year', columns='mnth', values='tavg')
data.columns = months

plt.subplots(figsize=(10,10))
sns.heatmap(data, cmap='YlOrRd',annot=True, fmt='.1f')
plt.title('Average Daily Temperature (C) by Month')
plt.yticks(rotation=0)
plt.show()

# %%
month_df = bangalore_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()
data = month_df.pivot(index='year', columns='mnth', values='prcp')
#data = month_df.pivot('year','mnth','prcp')
data.columns = months

plt.subplots(figsize=(10,10))
sns.heatmap(data,cmap='Blues',annot=True, fmt='.1f')
plt.title('Average Daily Precipitation (mm) by Month')
plt.yticks(rotation=0)
plt.show()
month_df = mumbai_df.groupby(['year','mnth'], as_index=False)[['tavg','prcp']].mean()
data = month_df.pivot(index='year', columns='mnth', values='prcp')
#data = month_df.pivot('year','mnth','prcp')
data.columns = months

plt.subplots(figsize=(10,10))
sns.heatmap(data,cmap='Blues',annot=True, fmt='.1f')
plt.title('Average Daily Precipitation (mm) by Month')
plt.yticks(rotation=0)
plt.show()

# %%
data = mumbai_df[mumbai_df['year'].isin([1990,2016])]

plt.subplots(figsize=(15,6))
sns.boxplot(x='mnth', y='tavg', hue='year', data=data,saturation=1)
plt.xlabel('Month')
plt.ylabel('Temerature (C)')
plt.title('Temperature 1990 vs 2016');


data = bangalore_df[bangalore_df['year'].isin([1990,2016])]

plt.subplots(figsize=(15,6))
sns.boxplot(x='mnth', y='tavg', hue='year', data=data,saturation=1)
plt.xlabel('Month')
plt.ylabel('Temerature (C)')
plt.title('Temperature 1990 vs 2016');

# %%
data = mumbai_df[mumbai_df['year'].isin([1990,2016])]
plt.subplots(figsize=(15,6))
sns.barplot(x='mnth',y='prcp', hue='year', data=data,ci=None)
plt.xlabel('Month')
plt.ylabel('Precipitation (mm)')
plt.title('Precipitation 1990 vs 2016');

data = bangalore_df[bangalore_df['year'].isin([1990,2016])]

plt.subplots(figsize=(15,6))
sns.barplot(x='mnth',y='prcp', hue='year', data=data,ci=None)
plt.xlabel('Month')
plt.ylabel('Precipitation (mm)')
plt.title('Precipitation 1990 vs 2016');
# Out:
# <ipython-input-141-3a2db5b98e60>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='mnth',y='prcp', hue='year', data=data,ci=None)
# <ipython-input-141-3a2db5b98e60>:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='mnth',y='prcp', hue='year', data=data,ci=None)

# %% [markdown]
# #Conclusion for Weather Data Analysis of Bangalore and Mumbai (1990-2022)

# %% [markdown]
# Temperature Trends:
#
# Mumbai: The average temperature in Mumbai has shown a steady increase from 1990 to 2022, reflecting global warming effects. The increase is more pronounced in the summer months (April to June), indicating hotter summers in recent years.
#
# Bangalore: The average temperature in bangalore is more or less the same since 1990.Precipitation has a negative trend past the year 2015. However, there is a clear trend of warmer winters, with minimum temperatures rising over the years.
# Monthly and Seasonal Comparison:
#
# Mumbai: The city's tropical climate leads to less variation in monthly temperatures. However, the analysis reveals a more noticeable rise in the pre-monsoon and monsoon months (June to September), suggesting that Mumbai is experiencing warmer monsoons.
#
# Bangalore: The seasonal variations are more distinct, with the city seeing slightly warmer temperatures during the winter months (December to February) over time, indicating milder winters. The summer months also show an upward trend in temperature, although not as steep as in Mumbai.
# Comparison Between 1990 and 2016:
#
# In both cities, the box plots for 1990 and 2016 reveal a general upward shift in the median temperatures across most months. The spread of temperatures (shown by the box sizes) is also larger in 2016, indicating more temperature variability in recent years.
# Mumbai: The increase is particularly noticeable in the pre-monsoon and monsoon seasons, with the 2016 data showing consistently higher temperatures compared to 1990.
# Bangalore: The increase is less extreme but still visible, with notable warming during the winter months in 2016.
# Climate Variability:
#
# Mumbai: Being a coastal city, Mumbai’s temperatures are influenced by its proximity to the Arabian Sea. However, the data shows that the city's climate is becoming warmer, especially in the monsoon period, which might impact the frequency and intensity of rainfall.
# Bangalore: As a city located on a plateau, Bangalore enjoys a more temperate climate. However, its weather has also become warmer, especially in winter and early summer, pointing to potential changes in its mild climate.
# Warming Patterns:
#
# Both cities are experiencing the effects of global climate change, with clear warming trends over the period from 1990 to 2022.
# Mumbai is seeing more significant increases in average temperature.
# Bangalore, though more moderate, is not exempt from these changes, with noticeable warming in both summer and winter months.

# %% [markdown]
# RECOMMENDATION:

# %% [markdown]
# 1. Temperature
# Bangalore:
#
# Known for its moderate and pleasant climate, with average temperatures generally ranging between 20°C and 25°C.
# Temperature fluctuations are mild, with fewer extreme hot days.
# Cooler during the winter months, with lower minimum temperatures.
# Mumbai:
#
# Has a tropical climate, with higher average temperatures, especially during summer (March–June), where temperatures can frequently exceed 30°C.
# Mumbai experiences hotter and more humid conditions due to its coastal location.
# Minimum temperatures remain warmer compared to Bangalore throughout the year.
# Recommendation:
#
# Bangalore’s moderate climate makes it more comfortable for year-round outdoor activities and living, especially if you prefer cooler weather.
# Mumbai may suit individuals who can handle heat and humidity better, especially during the summer months.
# 2. Rainfall (Precipitation)
# Bangalore:
# Receives moderate rainfall, mostly concentrated in the monsoon months (June–September).
# Rainfall is generally lower than in Mumbai, with fewer chances of flooding.
# Mumbai:
# Experiences heavy monsoons, with significant rainfall between June and September, often leading to flooding and traffic issues.
# Rainfall can be intense, disrupting daily life, especially during peak monsoon periods.
# Recommendation:
#
# Bangalore offers a more balanced experience with fewer rainfall-related disruptions, making it ideal for those who prefer less rain.
# If you're drawn to coastal living and can handle the challenges of heavy monsoons, Mumbai could be a better fit, but you’ll need to be prepared for potential monsoon-related issues.
# 3. Seasonal Variation
# Bangalore:
# Has relatively stable weather throughout the year with no harsh extremes in any season.
# More comfortable during summer compared to many other Indian cities.
# Mumbai:
# Experiences high humidity year-round, with the summer months being particularly hot and sticky.
# The monsoon period can bring both respite from the heat and challenges due to flooding.
# Recommendation:
#
# Bangalore is well-suited for those who prefer a stable, comfortable climate throughout the year.
# Mumbai’s weather is better for people who enjoy the vibrancy of a coastal city and are willing to cope with the heat and humidity.
# 4. Lifestyle and Activities
# Bangalore:
# Its cooler temperatures make it favorable for outdoor activities, hiking, and gardening.
# Known as the "Silicon Valley of India," the tech industry thrives here, and the climate supports a healthy work-life balance.
# Mumbai:
# While outdoor activities might be limited during the summer and monsoon, the city offers a dynamic urban lifestyle.
# Mumbai’s coastal location also means easy access to beaches and water-based activities, although weather might restrict certain activities during the monsoon.
# Recommendation:
#
# For a balanced work-life atmosphere with fewer weather disruptions, Bangalore is ideal.
# If you're drawn to a fast-paced, dynamic environment and can handle the weather challenges, Mumbai offers a lot of energy and opportunities.
